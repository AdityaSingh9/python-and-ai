# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
### sentences
sent=[  'the glass of milk',
     'the glass of juice',
     'the cup of tea',
    'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good',]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## Define the vocabulary size
voc_size=10000

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
### One Hot Representation
one_hot_repr=[one_hot(words,voc_size)for words in sent]
one_hot_repr

## these index represents the words in vocab of size 10000
## directly not creating one hot representation instead using indexes
# Out:
# [[9479, 4531, 5840, 1253],
#  [9479, 4531, 5840, 5302],
#  [9479, 8829, 5840, 6882],
#  [1314, 1073, 3142, 4933, 5633],
#  [1314, 1073, 3142, 4933, 1109],
#  [2605, 9479, 107, 5840, 5471],
#  [9371, 9697, 5778, 4933]]

# %%
## word Embedding Representation

from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length=8       #maxlength of sentence (to keep dataset same )
embedded_docs=pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 9479 4531 5840 1253]
#  [   0    0    0    0 9479 4531 5840 5302]
#  [   0    0    0    0 9479 8829 5840 6882]
#  [   0    0    0 1314 1073 3142 4933 5633]
#  [   0    0    0 1314 1073 3142 4933 1109]
#  [   0    0    0 2605 9479  107 5840 5471]
#  [   0    0    0    0 9371 9697 5778 4933]]

# %%
## feature representation
dim=10

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')
# Out:
# /Users/adityakumarsingh/python/venv/lib/python3.12/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# array([[[ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.00306169,  0.02363719,  0.03327053,  0.03341601,
#          -0.01877053, -0.02747293, -0.00303843,  0.00589464,
#           0.02416563,  0.02986907],
#         [ 0.01637689,  0.02093012,  0.03014541,  0.0482075 ,
#           0.03560122, -0.02421414, -0.02890247, -0.03645258,
#          -0.00439868, -0.01236951],
#         [ 0.0008225 ,  0.03099317,  0.04404027, -0.02673099,
#          -0.02391135,  0.03449711, -0.01792326,  0.00222144,
#          -0.04607559, -0.02808998],
#         [-0.00456258, -0.03002174,  0.03161246,  0.03359148,
#           0.0421276 , -0.04925271,  0.03716392, -0.00192231,
#          -0.00118197, -0.00067754]],
#
#        [[ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.00306169,  0.02363719,  0.03327053,  0.03341601,
#          -0.01877053, -0.02747293, -0.00303843,  0.00589464,
#           0.02416563,  0.02986907],
#         [ 0.01637689,  0.02093012,  0.03014541,  0.0482075 ,
#           0.03560122, -0.02421414, -0.02890247, -0.03645258,
#          -0.00439868, -0.01236951],
#         [ 0.0008225 ,  0.03099317,  0.04404027, -0.02673099,
#          -0.02391135,  0.03449711, -0.01792326,  0.00222144,
#          -0.04607559, -0.02808998],
#         [ 0.0268419 ,  0.0175049 , -0.04836273, -0.02093456,
#           0.04693899,  0.0111477 , -0.03083948, -0.01916505,
#          -0.01890719, -0.04767988]],
#
#        [[ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.00306169,  0.02363719,  0.03327053,  0.03341601,
#          -0.01877053, -0.02747293, -0.00303843,  0.00589464,
#           0.02416563,  0.02986907],
#         [ 0.031205  ,  0.04231242, -0.01053456,  0.02700554,
#          -0.02157741,  0.00120791,  0.01480298,  0.00044994,
#           0.04632444,  0.03473469],
#         [ 0.0008225 ,  0.03099317,  0.04404027, -0.02673099,
#          -0.02391135,  0.03449711, -0.01792326,  0.00222144,
#          -0.04607559, -0.02808998],
#         [ 0.01210339,  0.00087257,  0.01247734, -0.0364063 ,
#           0.01321771,  0.02601054, -0.00054647, -0.02911756,
#           0.01819393, -0.04506139]],
#
#        [[ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [-0.0442316 , -0.00506725, -0.02735841, -0.02721001,
#          -0.02613344, -0.03461371, -0.04421543, -0.04058318,
#          -0.04922758, -0.04275421],
#         [-0.04123837,  0.04436621, -0.03729751,  0.01305908,
#          -0.03373677,  0.03295312, -0.0335989 , -0.02212789,
#           0.01160588, -0.04358947],
#         [-0.02541982,  0.02077034,  0.01650356, -0.00179309,
#          -0.02586557, -0.00660789,  0.03006191,  0.02972842,
#           0.00787711,  0.02900868],
#         [-0.01557616, -0.00856191,  0.03609646,  0.04536456,
#          -0.04378375, -0.00714505, -0.03958333,  0.02921945,
#           0.01468751, -0.0179754 ],
#         [-0.04606389, -0.01464419, -0.04102526,  0.02600243,
#           0.04588227,  0.00245326,  0.02446124,  0.01186197,
#          -0.04778788, -0.04565353]],
#
#        [[ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [-0.0442316 , -0.00506725, -0.02735841, -0.02721001,
#          -0.02613344, -0.03461371, -0.04421543, -0.04058318,
#          -0.04922758, -0.04275421],
#         [-0.04123837,  0.04436621, -0.03729751,  0.01305908,
#          -0.03373677,  0.03295312, -0.0335989 , -0.02212789,
#           0.01160588, -0.04358947],
#         [-0.02541982,  0.02077034,  0.01650356, -0.00179309,
#          -0.02586557, -0.00660789,  0.03006191,  0.02972842,
#           0.00787711,  0.02900868],
#         [-0.01557616, -0.00856191,  0.03609646,  0.04536456,
#          -0.04378375, -0.00714505, -0.03958333,  0.02921945,
#           0.01468751, -0.0179754 ],
#         [ 0.01787111,  0.02873322,  0.02606631,  0.01347399,
#           0.04385842,  0.01810894, -0.00911617, -0.03725579,
#           0.03858972, -0.04745096]],
#
#        [[ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [-0.04933631,  0.02866215, -0.0254625 , -0.01644449,
#          -0.0297604 ,  0.03669238, -0.03440261, -0.0444374 ,
#           0.03836692,  0.03051033],
#         [ 0.00306169,  0.02363719,  0.03327053,  0.03341601,
#          -0.01877053, -0.02747293, -0.00303843,  0.00589464,
#           0.02416563,  0.02986907],
#         [-0.030858  , -0.01458305,  0.03396164, -0.04919598,
#           0.0227781 , -0.01293281,  0.01508531, -0.00593104,
#          -0.04849856, -0.01636956],
#         [ 0.0008225 ,  0.03099317,  0.04404027, -0.02673099,
#          -0.02391135,  0.03449711, -0.01792326,  0.00222144,
#          -0.04607559, -0.02808998],
#         [ 0.02222177, -0.03321929,  0.01839782,  0.017629  ,
#          -0.02869555,  0.03653406,  0.03201573, -0.01604198,
#           0.0182747 , -0.04595874]],
#
#        [[ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [-0.04758729, -0.03385319,  0.03547982,  0.02745492,
#          -0.03865626, -0.01004155, -0.03374203, -0.01232555,
#           0.01515812, -0.02391188],
#         [ 0.04840774, -0.0342639 , -0.02927283, -0.04005743,
#           0.00348542,  0.04786569,  0.02786771,  0.02770469,
#           0.01915005, -0.02740321],
#         [ 0.02767606, -0.04703813, -0.03640541, -0.01289601,
#           0.02979526, -0.03082914,  0.04264301, -0.00372361,
#           0.00631949, -0.03349327],
#         [-0.01557616, -0.00856191,  0.03609646,  0.04536456,
#          -0.04378375, -0.00714505, -0.03958333,  0.02921945,
#           0.01468751, -0.0179754 ]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 9479, 4531, 5840, 1253], dtype=int32)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# array([[[ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.00306169,  0.02363719,  0.03327053,  0.03341601,
#          -0.01877053, -0.02747293, -0.00303843,  0.00589464,
#           0.02416563,  0.02986907],
#         [ 0.01637689,  0.02093012,  0.03014541,  0.0482075 ,
#           0.03560122, -0.02421414, -0.02890247, -0.03645258,
#          -0.00439868, -0.01236951],
#         [ 0.0008225 ,  0.03099317,  0.04404027, -0.02673099,
#          -0.02391135,  0.03449711, -0.01792326,  0.00222144,
#          -0.04607559, -0.02808998],
#         [-0.00456258, -0.03002174,  0.03161246,  0.03359148,
#           0.0421276 , -0.04925271,  0.03716392, -0.00192231,
#          -0.00118197, -0.00067754]],
#
#        [[ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.00306169,  0.02363719,  0.03327053,  0.03341601,
#          -0.01877053, -0.02747293, -0.00303843,  0.00589464,
#           0.02416563,  0.02986907],
#         [ 0.01637689,  0.02093012,  0.03014541,  0.0482075 ,
#           0.03560122, -0.02421414, -0.02890247, -0.03645258,
#          -0.00439868, -0.01236951],
#         [ 0.0008225 ,  0.03099317,  0.04404027, -0.02673099,
#          -0.02391135,  0.03449711, -0.01792326,  0.00222144,
#          -0.04607559, -0.02808998],
#         [ 0.0268419 ,  0.0175049 , -0.04836273, -0.02093456,
#           0.04693899,  0.0111477 , -0.03083948, -0.01916505,
#          -0.01890719, -0.04767988]],
#
#        [[ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.00306169,  0.02363719,  0.03327053,  0.03341601,
#          -0.01877053, -0.02747293, -0.00303843,  0.00589464,
#           0.02416563,  0.02986907],
#         [ 0.031205  ,  0.04231242, -0.01053456,  0.02700554,
#          -0.02157741,  0.00120791,  0.01480298,  0.00044994,
#           0.04632444,  0.03473469],
#         [ 0.0008225 ,  0.03099317,  0.04404027, -0.02673099,
#          -0.02391135,  0.03449711, -0.01792326,  0.00222144,
#          -0.04607559, -0.02808998],
#         [ 0.01210339,  0.00087257,  0.01247734, -0.0364063 ,
#           0.01321771,  0.02601054, -0.00054647, -0.02911756,
#           0.01819393, -0.04506139]],
#
#        [[ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [-0.0442316 , -0.00506725, -0.02735841, -0.02721001,
#          -0.02613344, -0.03461371, -0.04421543, -0.04058318,
#          -0.04922758, -0.04275421],
#         [-0.04123837,  0.04436621, -0.03729751,  0.01305908,
#          -0.03373677,  0.03295312, -0.0335989 , -0.02212789,
#           0.01160588, -0.04358947],
#         [-0.02541982,  0.02077034,  0.01650356, -0.00179309,
#          -0.02586557, -0.00660789,  0.03006191,  0.02972842,
#           0.00787711,  0.02900868],
#         [-0.01557616, -0.00856191,  0.03609646,  0.04536456,
#          -0.04378375, -0.00714505, -0.03958333,  0.02921945,
#           0.01468751, -0.0179754 ],
#         [-0.04606389, -0.01464419, -0.04102526,  0.02600243,
#           0.04588227,  0.00245326,  0.02446124,  0.01186197,
#          -0.04778788, -0.04565353]],
#
#        [[ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [-0.0442316 , -0.00506725, -0.02735841, -0.02721001,
#          -0.02613344, -0.03461371, -0.04421543, -0.04058318,
#          -0.04922758, -0.04275421],
#         [-0.04123837,  0.04436621, -0.03729751,  0.01305908,
#          -0.03373677,  0.03295312, -0.0335989 , -0.02212789,
#           0.01160588, -0.04358947],
#         [-0.02541982,  0.02077034,  0.01650356, -0.00179309,
#          -0.02586557, -0.00660789,  0.03006191,  0.02972842,
#           0.00787711,  0.02900868],
#         [-0.01557616, -0.00856191,  0.03609646,  0.04536456,
#          -0.04378375, -0.00714505, -0.03958333,  0.02921945,
#           0.01468751, -0.0179754 ],
#         [ 0.01787111,  0.02873322,  0.02606631,  0.01347399,
#           0.04385842,  0.01810894, -0.00911617, -0.03725579,
#           0.03858972, -0.04745096]],
#
#        [[ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [-0.04933631,  0.02866215, -0.0254625 , -0.01644449,
#          -0.0297604 ,  0.03669238, -0.03440261, -0.0444374 ,
#           0.03836692,  0.03051033],
#         [ 0.00306169,  0.02363719,  0.03327053,  0.03341601,
#          -0.01877053, -0.02747293, -0.00303843,  0.00589464,
#           0.02416563,  0.02986907],
#         [-0.030858  , -0.01458305,  0.03396164, -0.04919598,
#           0.0227781 , -0.01293281,  0.01508531, -0.00593104,
#          -0.04849856, -0.01636956],
#         [ 0.0008225 ,  0.03099317,  0.04404027, -0.02673099,
#          -0.02391135,  0.03449711, -0.01792326,  0.00222144,
#          -0.04607559, -0.02808998],
#         [ 0.02222177, -0.03321929,  0.01839782,  0.017629  ,
#          -0.02869555,  0.03653406,  0.03201573, -0.01604198,
#           0.0182747 , -0.04595874]],
#
#        [[ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [ 0.01115944,  0.00142312, -0.03840214,  0.03577589,
#           0.0491298 , -0.010794  ,  0.04591933, -0.03709482,
#          -0.03004628, -0.00674512],
#         [-0.04758729, -0.03385319,  0.03547982,  0.02745492,
#          -0.03865626, -0.01004155, -0.03374203, -0.01232555,
#           0.01515812, -0.02391188],
#         [ 0.04840774, -0.0342639 , -0.02927283, -0.04005743,
#           0.00348542,  0.04786569,  0.02786771,  0.02770469,
#           0.01915005, -0.02740321],
#         [ 0.02767606, -0.04703813, -0.03640541, -0.01289601,
#           0.02979526, -0.03082914,  0.04264301, -0.00372361,
#           0.00631949, -0.03349327],
#         [-0.01557616, -0.00856191,  0.03609646,  0.04536456,
#          -0.04378375, -0.00714505, -0.03958333,  0.02921945,
#           0.01468751, -0.0179754 ]]], dtype=float32)
